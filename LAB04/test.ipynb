# %%
board = [[' ' for _ in range(3)] for _ in range(3)]

# %%
x = input().split()
x1, y1 = map(int ,x )
print(x1, y1)
# Out:
# 2 3

# %%
board  = [2*(i+1) for i in range(3)]
print(board)

# %%
board[0].append([" "])

# %%
print(board)
